# %% [markdown]
# > **Problem :** Implement a decision tree classifier on a dataset of your choice (e.g., Iris dataset) using Scikit-Learn and visualize the resulting decision tree.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import warnings

# %%
def dectree(max):
    data = pd.read_csv('iris.csv')
    encoder = LabelEncoder()
    data['species']= encoder.fit_transform(data['species'])
    x = data.iloc[:,0:2]
    y = data.iloc[:,4]
    
    dtc = DecisionTreeClassifier(max_depth=max)
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)
    dtc.fit(x_train,y_train)

    y_pred = dtc.predict(x_test)
    print('Tree Depth :', max)
    print('Accuracy :',accuracy_score(y_test,y_pred))
    warnings.filterwarnings("ignore")
    from mlxtend.plotting import plot_decision_regions
    plt.figure(figsize=(6, 5))
    plot_decision_regions(x_train.values,y_train.values,dtc,legend =2)
    warnings.filterwarnings("default")
    plt.xlabel('sepal length [cm]')
    plt.ylabel('petal length [cm]')
    plt.title('DecisionTreeClassifier on Iris')
    plt.show()

# %%
import time 
max_depths = [1, 2, 3, 4, 5]
for depth in max_depths:
    dectree(depth) #call
    time.sleep(1.6)
# Out:
# Tree Depth : 1
# Accuracy : 0.6333333333333333
# Tree Depth : 2
# Accuracy : 0.8
# Tree Depth : 3
# Accuracy : 0.8333333333333334
# Tree Depth : 4
# Accuracy : 0.8333333333333334
# Tree Depth : 5
# Accuracy : 0.7333333333333333
